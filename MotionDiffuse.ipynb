# %% [markdown]
# <a href="https://colab.research.google.com/github/yzihan/Generative-AI/blob/main/MotionDiffuse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MotionDiffuse: Text-Driven Human Motion Generation with Diffusion Model
#
# Authored by Mingyuan Zhang, Zhongang Cai, Liang Pan, Fangzhou Hong, Xinying Guo, Lei Yang, Ziwei Liu.
#
# This colab notebook provides a quick example of text-driven motion generation with our pretrained models.
#
# For more information, feel free to visit our project page (https://mingyuan-zhang.github.io/projects/MotionDiffuse.html).

# %% [markdown]
# ## Preparation
#
# Install necessities and download datas for **MotionDiffuse**

# %%
# !apt install ffmpeg
# !pip install git+https://github.com/openai/CLIP.git
# !pip install mmcv
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.11-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/openai/CLIP.git to /tmp/pip-req-build-5j75ltob
#   Running command git clone -q https://github.com/openai/CLIP.git /tmp/pip-req-build-5j75ltob
# ...
#      |████████████████████████████████| 53 kB 1.6 MB/s
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369409 sha256=33e4faa4225c6c24ce998e045964a178f2d68bcf1827a976c0974b56d2f9b76a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n8am3yh2/wheels/fd/b9/c3/5b4470e35ed76e174bff77c92f91da82098d5e35fd5bc8cdac
# Successfully built clip
# ...

# %%
# !gdown https://drive.google.com/uc?id=1vzBZ2rNCQWBQpYvC6hpyJfR3iK1O_FEG
# !unzip MotionDiffuse.zip
# !rm MotionDiffuse.zip
import os
os.chdir("MotionDiffuse")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1vzBZ2rNCQWBQpYvC6hpyJfR3iK1O_FEG
# To: /content/MotionDiffuse.zip
# 100% 711M/711M [00:03<00:00, 224MB/s]
# Archive:  MotionDiffuse.zip
#    creating: MotionDiffuse/
#    creating: MotionDiffuse/checkpoints/
#    creating: MotionDiffuse/checkpoints/t2m/
#    creating: MotionDiffuse/checkpoints/t2m/t2m_motiondiffuse/
#    creating: MotionDiffuse/checkpoints/t2m/t2m_motiondiffuse/meta/
#   inflating: MotionDiffuse/checkpoints/t2m/t2m_motiondiffuse/meta/mean.npy
#   inflating: MotionDiffuse/checkpoints/t2m/t2m_motiondiffuse/meta/std.npy
#    creating: MotionDiffuse/checkpoints/t2m/t2m_motiondiffuse/model/
#   inflating: MotionDiffuse/checkpoints/t2m/t2m_motiondiffuse/model/latest.tar
#   inflating: MotionDiffuse/checkpoints/t2m/t2m_motiondiffuse/opt.txt
#    creating: MotionDiffuse/datasets/
#   inflating: MotionDiffuse/datasets/dataloader.py
#   inflating: MotionDiffuse/datasets/dataset.py
# ...

# %% [markdown]
# ## Visualization
# You can visualize human motion with the given language description and the expected motion length.

# %%
# %env PYTHONPATH=.:$PYTHONPATH
# !python -u tools/visualization.py \
    --opt_path checkpoints/t2m/t2m_motiondiffuse/opt.txt \
    --text "a person is jumping" \
    --motion_length 60 \
    --result_path "test_sample.mp4"
# Out:
# env: PYTHONPATH=.:$PYTHONPATH
# No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
# Reading checkpoints/t2m/t2m_motiondiffuse/opt.txt
# 100%|████████████████████████████████████████| 338M/338M [00:02<00:00, 135MiB/s]
# 100% 1000/1000 [01:56<00:00,  8.61it/s]

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('test_sample.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
